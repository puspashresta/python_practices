# %%
from bs4 import BeautifulSoup
import requests

res=requests.get(f"https://www.worldometers.info/coronavirus/",'html.parser')
data=res.text
soup=BeautifulSoup(data,'lxml')

table_tag=soup.find('table')
table_tag
# Out:
# <table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br/>Other</th>
# <th width="20">Total<br/>Cases</th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">New<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# </tr>
# </thead>
# <tbody>
# ...

# %%
from bs4 import BeautifulSoup
import requests

res=requests.get(f"https://www.worldometers.info/coronavirus/",'html.parser')
data=res.text
soup=BeautifulSoup(data,'lxml')

table_tag=soup.find('table')
table_tags=table_tag.findAll('tr')
#table_tags
#make list to add data
#table_tag=table_tag[1:-5]
data_list=[]
for x in table_tags:
    data_list.append(x.get_text())
    
data_list[0].split()
# Out:
# ['#',
#  'Country,Other',
#  'TotalCases',
#  'NewCases',
#  'TotalDeaths',
#  'NewDeaths',
#  'TotalRecovered',
#  'NewRecovered',
#  'ActiveCases',
#  'Serious,Critical',
#  'Tot',
#  'Cases/1M',
#  'pop',
#  'Deaths/1M',
#  'pop',
#  'TotalTests',
#  'Tests/',
#  '1M',
#  'pop',
#  'Population',
#  'Continent',
#  '1',
#  'Caseevery',
#  'X',
#  'ppl1',
#  'Deathevery',
#  'X',
#  'ppl1',
#  'Testevery',
#  'X',
#  'ppl']

# %%
from bs4 import BeautifulSoup
import requests

finaldata=[]
res=requests.get(f"https://www.worldometers.info/coronavirus/",'html.parser')
data=res.text
soup=BeautifulSoup(data,'lxml')

table_tag=soup.find('table')
table_tags=table_tag.findAll('tr')
table_tags=table_tags[0:-1] # used to select rows of table
#make list to add data
data_list=[]

for x in table_tags:
    data_list.append(x.get_text())
    
#data_list[0].split('\n')

for y in range(len(data_list)):
    finaldata.append(data_list[y][0:-1].split())
    
finaldata
# Out:
# [['#',
#   'Country,Other',
#   'TotalCases',
#   'NewCases',
#   'TotalDeaths',
#   'NewDeaths',
#   'TotalRecovered',
#   'NewRecovered',
#   'ActiveCases',
#   'Serious,Critical',
#   'Tot',
#   'Cases/1M',
#   'pop',
#   'Deaths/1M',
#   'pop',
#   'TotalTests',
#   'Tests/',
#   '1M',
#   'pop',
#   'Population',
#   'Continent',
#   '1',
#   'Caseevery',
#   'X',
#   'ppl1',
#   'Deathevery',
#   'X',
#   'ppl1',
#   'Testevery',
#   'X',
#   'ppl'],
#  ['North',
#   'America',
#   '2,282,752',
#   '+4,272',
#   '135,758',
#   '+221',
#   '930,372',
#   '+3,075',
#   '1,216,622',
#   '19,441',
#   'North',
#   'America'],
#  ['South',
#   'America',
#   '1,146,755',
#   '+285',
#   '51,046',
#   '+824',
#   '531,548',
#   '+184',
#   '564,161',
#   '11,783',
#   'South',
#   'America'],
#  ['Europe',
#   '2,104,149',
#   '+9,841',
#   '179,089',
#   '+146',
#   '1,087,015',
#   '+4,887',
#   '838,045',
#   '7,166',
#   'Europe'],
#  ['Asia',
#   '1,372,213',
#   '+10,984',
# ...

# %%
import csv

len_list=len(finaldata)
try:
    with open("Project3.csv","w") as csvFile:
        for i in range(len_list):
            w=csv.writer(csvFile)
            w.writerow(finaldata[i])
        print("Succeed")
except:
    print("Error occured")
# Out:
# Succeed

# %%
import pandas as p

obj=p.read_csv("Project1.csv",nrows=15)#Project 3 rakheko maa error dekhako xa
obj
# Out:
#           # Country,Other TotalCases NewCases TotalDeaths  NewDeaths  \
# 0     North       America  2,282,663   +4,183     135,758       +221
# 1     South       America  1,146,755     +285      51,046       +824
# 2    Europe     2,104,007     +9,699  179,078        +135  1,086,991
# 3      Asia     1,368,045     +6,816   35,117         +92    823,936
# 4    Africa       192,118      5,215   84,919     101,984        469
# 5   Oceania         8,875         +5      124       8,293         +4
# 6       721            15        651       55           4        NaN
# 7     World     7,103,184    +20,988  406,353      +1,272  3,466,691
# 8         1           USA  2,007,449  112,469     761,708  1,133,272
# 9         2        Brazil    691,962   37,312        +813    302,084
# 10        3        Russia    476,658   +8,985       5,971       +112
# 11        4         Spain    288,630   27,136         NaN        NaN
# 12        5            UK    286,194   40,542         NaN        NaN
# ...

# %%
import pandas as p

df=p.read_csv("Project1.csv",usecols=['#','Country,Other','TotalCases','TotalDeaths','TotalRecovered','ActiveCases'],nrows=25)
df
# Out:
#           # Country,Other TotalCases TotalDeaths TotalRecovered  \
# 0     North       America  2,282,663     135,758        930,353
# 1     South       America  1,146,755      51,046        531,548
# 2    Europe     2,104,007     +9,699        +135         +4,863
# 3      Asia     1,368,045     +6,816         +92         +1,640
# 4    Africa       192,118      5,215     101,984         Africa
# 5   Oceania         8,875         +5       8,293            458
# 6       721            15        651           4            NaN
# 7     World     7,103,184    +20,988      +1,272         +9,747
# 8         1           USA  2,007,449     761,708         16,923
# 9         2        Brazil    691,962        +813        352,566
# 10        3        Russia    476,658       5,971        230,688
# 11        4         Spain    288,630         NaN            NaN
# 12        5            UK    286,194         NaN            NaN
# 13        6         India    258,090       7,207           +247
# ...

# %%
#iloc[0:3,3:8] for row and col

#loc[2:8] searches rows only

# %%
from matplotlib import pyplot as py

usecols=['#','Country,Other','TotalCases','TotalDeaths','TotalRecovered','ActiveCases'],
